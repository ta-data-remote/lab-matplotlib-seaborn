# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
ig2,axes2 = plt.subplots(1,2,figsize = (20,6))
axes2[0].plot(x,y, label='y = x*2')
plt.plot(x,y, )
plt.plot(x,z, label='z = x**2')

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
plt.figure(figsize = (20,6))
plt.subplot(1,2,1)
plt.plot(x,y, label='y =x*2')
plt.legend()
plt.subplot(1,2,1.5)
plt.plot(x,z, label=' z =x**2')
plt.legend()
# Out:
# <ipython-input-9-0fd98b0f881f>:6: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(1,2,1.5)

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, ax = plt.subplots(1,2, figsize = (10,3))
ax[0].plot(x,y, label='y = x*2')
ax[1].plot(x,z, label='z = x**2')
for i in ax:    
    i.legend()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

         
y = x**2
y1 = np.e**x
fig, ax = plt.subplots(1,2, figsize = (10,8))
ax[0].plot(x,y, label='x**2')
ax[1].set_yscale('log')
ax[1].plot(x,y1, label='exp(x)')
ax[0].legend()
ax[1].legend()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv(r'C:\Users\User\Documents\Github\data\Fitbit2.csv')

# %%
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# your code here

# %%
fitbit["Months"] = pd.to_datetime(fitbit.Months, format='%b', errors='coerce').dt.month

total = fitbit.groupby(fitbit["Months"])["Steps"].median()
total

x = sns.lineplot(x=steps_by_month.index ,y =steps_by_month)

steps_by_weekend = fitbit.groupby("Work_or_Weekend")["Steps"].median()
steps_by_weekend

y = sns.barplot(x=steps_by_weekend.index ,y =steps_by_weekend
# Out:
# ([<matplotlib.axis.XTick at 0x1c4ac3ec220>,
# ...
#  [Text(0, 0, 'Weekend'), Text(0, 0, 'Workdays')])

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
heart_CAT = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']
  
a = 1  # rows
b = 3  # columns
c = 1  # initialize plot counter
    
fig = plt.figure(figsize=(14,10))

for i in heart_CAT:
    plt.subplot(a, b, c)
    plt.title('{} (scatter), subplot: {}{}{}'.format(i, a, b, c))
    plt.xlabel(i)
    sns.scatterplot(data = fitbit, x = i, y = 'Steps')
    c = c + 1
    
plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv(r'C:\Users\User\Documents\Github\data\titanic.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-7e0cd7e259fd> in <module>
#       1 # your code here
# ----> 2 titanic = pd.read_csv(r'C:\Users\User\Documents\Github\data\titanic.csv')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtype
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(include=np.number).columns.tolist()
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(include=object).columns.tolist()
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here 'search for plt set style'
plt.style.use('classic')
plt.figure(figsize = (12,6))
x = titanic.plot(x="Age", kind="bar",figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here


hist = titanic["Age"].hist(bins=10)
# Out:
# (array([ 72.,  78., 326., 347., 220., 136.,  75.,  42.,  10.,   3.]),
#  array([ 0.17 ,  8.153, 16.136, 24.119, 32.102, 40.085, 48.068, 56.051,
#         64.034, 72.017, 80.   ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here 
hist = titanic["Age"].hist(bins=10)
hist = titanic["Age"].hist(bins=20)
hist = titanic["Age"].hist(bins=50)

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
#it gets smaller by increasing the bins

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.displot(titanic, x="Age")

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
gender = titanic['Gender'].value_counts()
sns.barplot(x=gender.index ,y=gender)
# Out:
# <BarContainer object of 2 artists>

# %%
# Method 2 - seaborn
# your code here
gender = titanic['Gender'].value_counts()
ax = sns.barplot(x=gender.index ,y=gender)
for bar_container, shade in zip(ax.containers, [0.5, 0.9]):
    for bar, group_cmap in zip(bar_container, ['Reds', 'Blues']):
        bar.set_color(plt.get_cmap(group_cmap)(shade))

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
p_class = titanic['Pclass'].value_counts()
sns.barplot(x=p_class.index ,y =p_class)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
plt.boxplot(titanic['Age'])
plt.title('Age')

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
#the range goes from ca 25 to 40 and the median lays at  30

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.set_theme(style="whitegrid")
titanic = sns.load_dataset("titanic")
ax = sns.violinplot(y=titanic["Age"])

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
#it shows the mean and the propotion to the others

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.scatter(titanic["Age"], titanic["Fare"])
plt.show()

# %%
# Method 2 - seaborn 
# your code here 

sns.scatterplot(data = titanic, x = "Age", y = "Fare")
plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here 'there's a method for this' 

heatmap = sns.heatmap(titanic.corr(), vmin=-1, vmax=1, annot=True)
 
heatmap.set_title('Correlation matrix', fontdict={'fontsize':14}, pad=14)

# %% [markdown]
# #### What are the most correlated features?

# %%
#PClass and Fare

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.boxplot(y='Age', x='Pclass', data=titanic, palette="colorblind")

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here 
sns.displot(titanic, x="Age", hue="Gender", multiple="stack")

# %%
# Out:
# (array([ 31.,  33., 100., 117.,  83.,  48.,  28.,  19.,   6.,   1.]),
#  array([ 0.17 ,  7.753, 15.336, 22.919, 30.502, 38.085, 45.668, 53.251,
#         60.834, 68.417, 76.   ]),
#  <a list of 10 Patch objects>)
