# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1


fig, ax = plt.subplots(figsize = (12,5))

ax.plot(x,y, c="g", linewidth=5) 
ax.plot(x,z, c="r", linewidth=5)

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2

fig2,ax2 = plt.subplots(1,2)
fig2.suptitle('My second Matplotlib plot(s)', fontsize=18)

ax2[0].plot(x,y, c="g", linewidth=5)
ax2[0].set_title('Linear plot', fontsize=15)

ax2[1].plot(x,z, c="r", linewidth=5)
ax2[1].set_title('Explonential plot', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Explonential plot')

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here

fig3,ax3 = plt.subplots(1,2,figsize=(15,5))
fig3.suptitle('My second Matplotlib plot(s)', fontsize=18)

ax3[0].plot(x,y, c="g", linewidth=5.0, label="xy")
ax3[0].set_title('Linear plot', fontsize=15)

ax3[1].plot(x,z, c="r", linewidth=5.0, label="xz")
ax3[1].set_title('Explonential plot', fontsize=15)  

ax3[0].set_xlabel("x")
ax3[0].set_ylabel("y")
ax3[1].set_xlabel("x")
ax3[1].set_ylabel("z")

ax3[0].legend()
ax3[1].legend()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here

y1 = np.square(x)
y2 = np.exp(x)

fig4, ax4 = plt.subplots(1,2,figsize=(15,5))

ax4[0].plot(x,y1, c="g", linewidth=5.0, label="x*y1")
ax4[0].set_title('Linear plot', fontsize=15)

ax4[1].plot(x,y2, c="r", linewidth=5.0, label="x*y2")
ax4[1].set_title('Explonential plot', fontsize=15)  

ax4[1].set_yscale('log')
ax4[1].set_xscale('log')

ax4[0].set_xlabel("x")
ax4[0].set_ylabel("y1")
ax4[1].set_xlabel("x")
ax4[1].set_ylabel("y2")

ax4[0].legend()
ax4[1].legend()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here

fitbit_db = pd.read_csv('D:\Data Science\Ironhack\GitHub\Week 5\lab-matplotlib-seaborn\data\Fitbit2.csv')
fitbit = fitbit_db.copy()

fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# 0               1680  ...        0.403891    Friday           4.0
# 1               2248  ...        8.767545  Saturday           5.0
# 2               1719  ...        6.567891    Sunday           6.0
# 3               9620  ...        3.119282    Monday           0.0
# 4               7360  ...        2.317714   Tuesday           1.0
#
#    Work_or_Weekend  Hours Sleep Sleep efficiency  Yesterday_sleep  \
# 0                1     6.400000        92.086331         0.000000
# 1                0     7.566667        92.464358         6.400000
# 2                0     6.450000        88.761468         7.566667
# 3                1     5.183333        88.857143         6.450000
# 4                1     6.783333        82.892057         5.183333
#
#    Yesterday_sleep_efficiency  Months  Months_encoded
# 0                    0.000000     May               5
# 1                   92.086331     May               5
# 2                   92.464358     May               5
# 3                   88.761468     May               5
# 4                   88.857143     May               5
#
# [5 rows x 24 columns]

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED

months_steps = fitbit.groupby(['Months_encoded'])['Steps'].median()
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

fig5, ax5 = plt.subplots(1, figsize=(12, 4))

plt.sca(ax5)
ax5.plot(months, months_steps, c="b", linewidth=5)
plt.xticks(np.arange(12), months)
ax5.set_title('Steps per Month', fontsize=15)

plt.savefig('../figures/month_steps.png')

# MEDIAN STEPS BY WORK_OR_WEEKEND

work_or_weekend_steps = fitbit.groupby(['Work_or_Weekend'])['Steps'].median()
week_or_weekend = ['Week', 'Weekend']

fig6, ax6 = plt.subplots(1, figsize=(12, 4))

plt.sca(ax6)
ax6.bar(week_or_weekend, work_or_weekend_steps, color=['r', 'g'])
plt.xticks(np.arange(2), week_or_weekend)
ax6.set_title('Steps per Week/Weekend', fontsize=15)

plt.savefig('../figures/weekly_steps.png')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

minutes = ['Minutes Lightly Active',
           'Minutes Very Active', 'Minutes Sedentary']

for plot in minutes:
    plt.figure(figsize=(12, 4))
    plt.title(plot)
    plt.scatter(fitbit[plot], fitbit['Steps'])

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

titanic_db = pd.read_csv('D:/Data Science/Ironhack/GitHub/Week 5/lab-matplotlib-seaborn/data/titanic.csv')
titanic = titanic_db.copy()

titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here


titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Gender       1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        1309 non-null   object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

titanic.select_dtypes(['int64', 'float64'])
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here

titanic.select_dtypes(['object'])
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# 3                 113803  C123        S
# 4                 373450    U0        S
# ...                  ...   ...      ...
# 1304           A.5. 3236    U0        S
# 1305            PC 17758  C105        C
# 1306  SOTON/O.Q. 3101262    U0        S
# 1307              359309    U0        S
# 1308                2668    U0        C
#
# [1309 rows x 5 columns]

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.figure(figsize=(12, 6))
plt.style.use('classic')
sns.set_style('white')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

plt.hist(titanic['Age'])
# Out:
# (array([ 72.,  78., 326., 347., 220., 136.,  75.,  42.,  10.,   3.]),
#  array([ 0.17 ,  8.153, 16.136, 24.119, 32.102, 40.085, 48.068, 56.051,
#         64.034, 72.017, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

fig7, ax7 = plt.subplots(1, 3, figsize=(16, 8))

sns.histplot(bins=10, color='orange',
             ax=ax7[0], data=titanic['Age']).set_title('10 bins')
sns.histplot(bins=20, color='brown',
             ax=ax7[1], data=titanic['Age']).set_title('20 bins')
sns.histplot(bins=50, color='pink',
             ax=ax7[2], data=titanic['Age']).set_title('50 bins')
# Out:
# Text(0.5, 1.0, '50 bins')

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
Bin size changes the count scale. The more bins the better because we can see our data more detailed.

"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

sns.histplot(titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

def my_fmt(x):
    print(x)
    return '{:.0f}%\n({:.0f})'.format(x, total*x/100)


values = titanic['Gender']
v_counts = values.value_counts()
total = len(values)
fig = plt.figure()
plt.pie(v_counts, labels=v_counts.index, autopct=my_fmt, shadow=True)
plt.style.use('default')
# Out:
# 64.40030336380005
# 35.59969365596771

# %%
# Method 2 - seaborn
# your code here

sns.countplot(x=titanic['Gender'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

sns.countplot(x=titanic['Pclass'])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

sns.boxplot(x=titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
Box plot, because it shows summary statistics and outliers. The plot shows the most people are between ~~22 and 38 years old.
There are just few people that are older than 60 years.
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

sns.violinplot(data=titanic, x='Age')
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
It shows me that, Age is normal distributed and mode is ~~29
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

plt.scatter(titanic['Age'], titanic['Fare'])
plt.xlabel("Age")
plt.ylabel("Fare")
# Out:
# Text(0, 0.5, 'Fare')

# %%
# Method 2 - seaborn
# your code here

sns.scatterplot(x=titanic['Age'], y=titanic['Fare'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
numerical = titanic.select_dtypes(['int64', 'float64'])

plt.figure(figsize=(12, 5))
heatmap = sns.heatmap(numerical.corr(), annot=True, cmap='Greens_r')

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here

Pclass - Fare

"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

sns.catplot(x='Pclass', y='Age', kind='box', data=titanic, height=3, aspect=2)

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here

sns.FacetGrid(data=titanic, hue='Gender', height=5).map(
    plt.hist, 'Age').add_legend()
